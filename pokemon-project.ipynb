# %% [markdown]
# ## Import section

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file

# %% [markdown]
# ## Print all the images from csv

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/pokemon.csv
# /kaggle/input/images/images/throh.png
# /kaggle/input/images/images/samurott.png
# /kaggle/input/images/images/venomoth.png
# /kaggle/input/images/images/latios.png
# /kaggle/input/images/images/shinx.png
# /kaggle/input/images/images/durant.png
# /kaggle/input/images/images/geodude.png
# /kaggle/input/images/images/wingull.png
# /kaggle/input/images/images/miltank.png
# /kaggle/input/images/images/castform.png
# /kaggle/input/images/images/squirtle.png
# /kaggle/input/images/images/shaymin-land.png
# /kaggle/input/images/images/raikou.png
# /kaggle/input/images/images/mawile.png
# /kaggle/input/images/images/gallade.png
# /kaggle/input/images/images/type-null.jpg
# /kaggle/input/images/images/patrat.png
# /kaggle/input/images/images/froslass.png
# /kaggle/input/images/images/lurantis.jpg
# /kaggle/input/images/images/nidoking.png
# /kaggle/input/images/images/magnemite.png
# /kaggle/input/images/images/cloyster.png
# /kaggle/input/images/images/spinarak.png
# /kaggle/input/images/images/meloetta-aria.png
# /kaggle/input/images/images/melmetal.jpg
# /kaggle/input/images/images/exploud.png
# /kaggle/input/images/images/vanillish.png
# /kaggle/input/images/images/scrafty.png
# /kaggle/input/images/images/azelf.png
# /kaggle/input/images/images/mew.png
# /kaggle/input/images/images/dialga.png
# /kaggle/input/images/images/cryogonal.png
# /kaggle/input/images/images/venonat.png
# /kaggle/input/images/images/scatterbug.png
# /kaggle/input/images/images/regigigas.png
# /kaggle/input/images/images/ferroseed.png
# /kaggle/input/images/images/butterfree.png
# /kaggle/input/images/images/komala.jpg
# /kaggle/input/images/images/porygon.png
# /kaggle/input/images/images/cosmoem.jpg
# /kaggle/input/images/images/tepig.png
# /kaggle/input/images/images/dragonite.png
# /kaggle/input/images/images/solgaleo.jpg
# /kaggle/input/images/images/paras.png
# /kaggle/input/images/images/scolipede.png
# /kaggle/input/images/images/smeargle.png
# /kaggle/input/images/images/pichu.png
# /kaggle/input/images/images/tropius.png
# /kaggle/input/images/images/typhlosion.png
# /kaggle/input/images/images/masquerain.png
# /kaggle/input/images/images/kecleon.png
# /kaggle/input/images/images/breloom.png
# /kaggle/input/images/images/inkay.png
# /kaggle/input/images/images/krabby.png
# /kaggle/input/images/images/pyukumuku.jpg
# /kaggle/input/images/images/minior-meteor.jpg
# /kaggle/input/images/images/swalot.png
# /kaggle/input/images/images/liepard.png
# /kaggle/input/images/images/cherrim.png
# /kaggle/input/images/images/taillow.png
# /kaggle/input/images/images/infernape.png
# /kaggle/input/images/images/raichu.png
# /kaggle/input/images/images/hypno.png
# /kaggle/input/images/images/charmander.png
# /kaggle/input/images/images/cleffa.png
# /kaggle/input/images/images/slowking.png
# /kaggle/input/images/images/quagsire.png
# /kaggle/input/images/images/furfrou.png
# /kaggle/input/images/images/snubbull.png
# /kaggle/input/images/images/palossand.jpg
# /kaggle/input/images/images/azurill.png
# /kaggle/input/images/images/barboach.png
# /kaggle/input/images/images/kakuna.png
# /kaggle/input/images/images/mankey.png
# /kaggle/input/images/images/zebstrika.png
# /kaggle/input/images/images/aggron.png
# /kaggle/input/images/images/bronzor.png
# /kaggle/input/images/images/onix.png
# /kaggle/input/images/images/horsea.png
# /kaggle/input/images/images/vileplume.png
# /kaggle/input/images/images/charjabug.jpg
# /kaggle/input/images/images/emboar.png
# /kaggle/input/images/images/kricketot.png
# /kaggle/input/images/images/metagross.png
# /kaggle/input/images/images/victini.png
# /kaggle/input/images/images/mudsdale.jpg
# /kaggle/input/images/images/ursaring.png
# /kaggle/input/images/images/garchomp.png
# /kaggle/input/images/images/sudowoodo.png
# /kaggle/input/images/images/hoppip.png
# /kaggle/input/images/images/tyranitar.png
# /kaggle/input/images/images/magearna.jpg
# /kaggle/input/images/images/bounsweet.jpg
# /kaggle/input/images/images/toucannon.jpg
# /kaggle/input/images/images/lotad.png
# /kaggle/input/images/images/klinklang.png
# /kaggle/input/images/images/dewott.png
# /kaggle/input/images/images/pangoro.png
# /kaggle/input/images/images/carvanha.png
# /kaggle/input/images/images/skitty.png
# /kaggle/input/images/images/tympole.png
# /kaggle/input/images/images/axew.png
# /kaggle/input/images/images/drifblim.png
# /kaggle/input/images/images/skuntank.png
# /kaggle/input/images/images/noctowl.png
# /kaggle/input/images/images/dugtrio.png
# /kaggle/input/images/images/articuno.png
# /kaggle/input/images/images/sentret.png
# /kaggle/input/images/images/loudred.png
# /kaggle/input/images/images/garbodor.png
# /kaggle/input/images/images/lugia.png
# /kaggle/input/images/images/nidoran-f.png
# /kaggle/input/images/images/magcargo.png
# /kaggle/input/images/images/chimchar.png
# /kaggle/input/images/images/drifloon.png
# /kaggle/input/images/images/marill.png
# /kaggle/input/images/images/gumshoos.jpg
# /kaggle/input/images/images/togedemaru.jpg
# /kaggle/input/images/images/croagunk.png
# /kaggle/input/images/images/doduo.png
# /kaggle/input/images/images/dusclops.png
# /kaggle/input/images/images/glameow.png
# /kaggle/input/images/images/crobat.png
# /kaggle/input/images/images/grumpig.png
# /kaggle/input/images/images/abomasnow.png
# /kaggle/input/images/images/xurkitree.jpg
# /kaggle/input/images/images/simisage.png
# /kaggle/input/images/images/frillish.png
# /kaggle/input/images/images/smoochum.png
# /kaggle/input/images/images/grubbin.jpg
# /kaggle/input/images/images/eelektrik.png
# /kaggle/input/images/images/dustox.png
# /kaggle/input/images/images/ivysaur.png
# /kaggle/input/images/images/dratini.png
# /kaggle/input/images/images/bulbasaur.png
# /kaggle/input/images/images/noibat.png
# /kaggle/input/images/images/necrozma.jpg
# /kaggle/input/images/images/cubchoo.png
# /kaggle/input/images/images/gorebyss.png
# /kaggle/input/images/images/hitmonchan.png
# /kaggle/input/images/images/glaceon.png
# /kaggle/input/images/images/deino.png
# /kaggle/input/images/images/aurorus.png
# /kaggle/input/images/images/wynaut.png
# /kaggle/input/images/images/ninetales.png
# /kaggle/input/images/images/pelipper.png
# /kaggle/input/images/images/petilil.png
# /kaggle/input/images/images/conkeldurr.png
# /kaggle/input/images/images/poliwrath.png
# /kaggle/input/images/images/toxapex.jpg
# /kaggle/input/images/images/mudbray.jpg
# /kaggle/input/images/images/steenee.jpg
# /kaggle/input/images/images/whiscash.png
# /kaggle/input/images/images/tapu-fini.jpg
# /kaggle/input/images/images/flabebe.png
# /kaggle/input/images/images/seedot.png
# /kaggle/input/images/images/comfey.jpg
# /kaggle/input/images/images/duosion.png
# /kaggle/input/images/images/darmanitan-standard.png
# /kaggle/input/images/images/volcarona.png
# /kaggle/input/images/images/wartortle.png
# /kaggle/input/images/images/dedenne.png
# /kaggle/input/images/images/pumpkaboo-average.png
# /kaggle/input/images/images/bellossom.png
# /kaggle/input/images/images/carbink.png
# /kaggle/input/images/images/ariados.png
# /kaggle/input/images/images/ferrothorn.png
# /kaggle/input/images/images/klink.png
# /kaggle/input/images/images/venusaur.png
# /kaggle/input/images/images/drilbur.png
# /kaggle/input/images/images/aegislash-blade.png
# /kaggle/input/images/images/karrablast.png
# /kaggle/input/images/images/sunkern.png
# /kaggle/input/images/images/golbat.png
# /kaggle/input/images/images/vikavolt.jpg
# /kaggle/input/images/images/guzzlord.jpg
# /kaggle/input/images/images/cranidos.png
# /kaggle/input/images/images/kangaskhan.png
# /kaggle/input/images/images/lopunny.png
# /kaggle/input/images/images/metang.png
# /kaggle/input/images/images/unfezant.png
# /kaggle/input/images/images/pawniard.png
# /kaggle/input/images/images/torterra.png
# /kaggle/input/images/images/glalie.png
# /kaggle/input/images/images/larvitar.png
# /kaggle/input/images/images/mesprit.png
# /kaggle/input/images/images/feraligatr.png
# /kaggle/input/images/images/giratina-altered.png
# /kaggle/input/images/images/pinsir.png
# /kaggle/input/images/images/dunsparce.png
# /kaggle/input/images/images/genesect.png
# /kaggle/input/images/images/skorupi.png
# /kaggle/input/images/images/slowbro.png
# /kaggle/input/images/images/leafeon.png
# /kaggle/input/images/images/diggersby.png
# /kaggle/input/images/images/girafarig.png
# /kaggle/input/images/images/shiftry.png
# /kaggle/input/images/images/naganadel.jpg
# /kaggle/input/images/images/staravia.png
# /kaggle/input/images/images/tornadus-incarnate.png
# /kaggle/input/images/images/barbaracle.png
# /kaggle/input/images/images/carracosta.png
# /kaggle/input/images/images/voltorb.png
# /kaggle/input/images/images/jirachi.png
# /kaggle/input/images/images/mr-mime.png
# /kaggle/input/images/images/clawitzer.png
# /kaggle/input/images/images/carnivine.png
# /kaggle/input/images/images/ponyta.png
# /kaggle/input/images/images/doublade.png
# /kaggle/input/images/images/finneon.png
# /kaggle/input/images/images/swampert.png
# /kaggle/input/images/images/vaporeon.png
# /kaggle/input/images/images/mewtwo.png
# /kaggle/input/images/images/arbok.png
# /kaggle/input/images/images/furret.png
# /kaggle/input/images/images/minun.png
# /kaggle/input/images/images/bibarel.png
# /kaggle/input/images/images/parasect.png
# /kaggle/input/images/images/lapras.png
# /kaggle/input/images/images/pidove.png
# /kaggle/input/images/images/zangoose.png
# /kaggle/input/images/images/croconaw.png
# /kaggle/input/images/images/quilladin.png
# /kaggle/input/images/images/escavalier.png
# /kaggle/input/images/images/gyarados.png
# /kaggle/input/images/images/basculin-red-striped.png
# /kaggle/input/images/images/sharpedo.png
# /kaggle/input/images/images/alakazam.png
# /kaggle/input/images/images/thundurus-incarnate.png
# /kaggle/input/images/images/vibrava.png
# /kaggle/input/images/images/dartrix.jpg
# /kaggle/input/images/images/bunnelby.png
# /kaggle/input/images/images/celesteela.jpg
# /kaggle/input/images/images/bastiodon.png
# /kaggle/input/images/images/oranguru.jpg
# /kaggle/input/images/images/nidorina.png
# /kaggle/input/images/images/fearow.png
# /kaggle/input/images/images/medicham.png
# /kaggle/input/images/images/shuppet.png
# /kaggle/input/images/images/gulpin.png
# /kaggle/input/images/images/groudon.png
# /kaggle/input/images/images/cubone.png
# /kaggle/input/images/images/gothita.png
# /kaggle/input/images/images/zigzagoon.png
# /kaggle/input/images/images/sceptile.png
# /kaggle/input/images/images/zekrom.png
# /kaggle/input/images/images/volbeat.png
# /kaggle/input/images/images/oddish.png
# /kaggle/input/images/images/beldum.png
# /kaggle/input/images/images/kingler.png
# /kaggle/input/images/images/hitmonlee.png
# /kaggle/input/images/images/togepi.png
# /kaggle/input/images/images/spearow.png
# /kaggle/input/images/images/armaldo.png
# /kaggle/input/images/images/latias.png
# /kaggle/input/images/images/tyrogue.png
# /kaggle/input/images/images/avalugg.png
# /kaggle/input/images/images/banette.png
# /kaggle/input/images/images/illumise.png
# /kaggle/input/images/images/lairon.png
# /kaggle/input/images/images/crustle.png
# /kaggle/input/images/images/sandslash.png
# /kaggle/input/images/images/diglett.png
# /kaggle/input/images/images/anorith.png
# /kaggle/input/images/images/vigoroth.png
# /kaggle/input/images/images/mienshao.png
# /kaggle/input/images/images/jolteon.png
# /kaggle/input/images/images/electabuzz.png
# /kaggle/input/images/images/skiddo.png
# /kaggle/input/images/images/combusken.png
# /kaggle/input/images/images/haunter.png
# /kaggle/input/images/images/luxray.png
# /kaggle/input/images/images/whimsicott.png
# /kaggle/input/images/images/dodrio.png
# /kaggle/input/images/images/porygon-z.png
# /kaggle/input/images/images/dwebble.png
# /kaggle/input/images/images/lileep.png
# /kaggle/input/images/images/azumarill.png
# /kaggle/input/images/images/serperior.png
# /kaggle/input/images/images/zorua.png
# /kaggle/input/images/images/golurk.png
# /kaggle/input/images/images/spinda.png
# /kaggle/input/images/images/passimian.jpg
# /kaggle/input/images/images/panpour.png
# /kaggle/input/images/images/pidgey.png
# /kaggle/input/images/images/simipour.png
# /kaggle/input/images/images/clamperl.png
# /kaggle/input/images/images/goldeen.png
# /kaggle/input/images/images/plusle.png
# /kaggle/input/images/images/cresselia.png
# /kaggle/input/images/images/xatu.png
# /kaggle/input/images/images/weavile.png
# /kaggle/input/images/images/heracross.png
# /kaggle/input/images/images/houndour.png
# /kaggle/input/images/images/bisharp.png
# /kaggle/input/images/images/herdier.png
# /kaggle/input/images/images/granbull.png
# /kaggle/input/images/images/pignite.png
# /kaggle/input/images/images/delcatty.png
# /kaggle/input/images/images/roselia.png
# /kaggle/input/images/images/gastly.png
# /kaggle/input/images/images/cacturne.png
# /kaggle/input/images/images/sylveon.png
# /kaggle/input/images/images/goomy.png
# /kaggle/input/images/images/bagon.png
# /kaggle/input/images/images/golett.png
# /kaggle/input/images/images/phantump.png
# /kaggle/input/images/images/floette.png
# /kaggle/input/images/images/togetic.png
# /kaggle/input/images/images/bonsly.png
# /kaggle/input/images/images/eevee.png
# /kaggle/input/images/images/hakamo-o.jpg
# /kaggle/input/images/images/numel.png
# /kaggle/input/images/images/floatzel.png
# /kaggle/input/images/images/eelektross.png
# /kaggle/input/images/images/shroomish.png
# /kaggle/input/images/images/misdreavus.png
# /kaggle/input/images/images/tapu-koko.jpg
# /kaggle/input/images/images/natu.png
# /kaggle/input/images/images/bewear.jpg
# /kaggle/input/images/images/lillipup.png
# /kaggle/input/images/images/lickilicky.png
# /kaggle/input/images/images/sunflora.png
# /kaggle/input/images/images/vullaby.png
# /kaggle/input/images/images/swinub.png
# /kaggle/input/images/images/larvesta.png
# /kaggle/input/images/images/swoobat.png
# /kaggle/input/images/images/kingdra.png
# /kaggle/input/images/images/druddigon.png
# /kaggle/input/images/images/sableye.png
# /kaggle/input/images/images/litwick.png
# /kaggle/input/images/images/gardevoir.png
# /kaggle/input/images/images/cinccino.png
# /kaggle/input/images/images/ekans.png
# /kaggle/input/images/images/blastoise.png
# /kaggle/input/images/images/keldeo-ordinary.png
# /kaggle/input/images/images/makuhita.png
# /kaggle/input/images/images/luvdisc.png
# /kaggle/input/images/images/pupitar.png
# /kaggle/input/images/images/mareanie.jpg
# /kaggle/input/images/images/magmar.png
# /kaggle/input/images/images/surskit.png
# /kaggle/input/images/images/empoleon.png
# /kaggle/input/images/images/mudkip.png
# /kaggle/input/images/images/yamask.png
# /kaggle/input/images/images/delibird.png
# /kaggle/input/images/images/seadra.png
# /kaggle/input/images/images/kirlia.png
# /kaggle/input/images/images/chingling.png
# /kaggle/input/images/images/excadrill.png
# /kaggle/input/images/images/silvally.jpg
# /kaggle/input/images/images/archeops.png
# /kaggle/input/images/images/landorus-incarnate.png
# /kaggle/input/images/images/arceus.png
# /kaggle/input/images/images/blissey.png
# /kaggle/input/images/images/sandshrew.png
# /kaggle/input/images/images/sawk.png
# /kaggle/input/images/images/whismur.png
# /kaggle/input/images/images/tapu-bulu.jpg
# /kaggle/input/images/images/bronzong.png
# /kaggle/input/images/images/wigglytuff.png
# /kaggle/input/images/images/accelgor.png
# /kaggle/input/images/images/honchkrow.png
# /kaggle/input/images/images/tirtouga.png
# /kaggle/input/images/images/whirlipede.png
# /kaggle/input/images/images/ditto.png
# /kaggle/input/images/images/budew.png
# /kaggle/input/images/images/florges.png
# /kaggle/input/images/images/diancie.png
# /kaggle/input/images/images/grotle.png
# /kaggle/input/images/images/murkrow.png
# /kaggle/input/images/images/venipede.png
# /kaggle/input/images/images/popplio.jpg
# /kaggle/input/images/images/crabrawler.jpg
# /kaggle/input/images/images/krookodile.png
# /kaggle/input/images/images/rockruff.jpg
# /kaggle/input/images/images/machop.png
# /kaggle/input/images/images/salandit.jpg
# /kaggle/input/images/images/buneary.png
# /kaggle/input/images/images/kyurem.png
# /kaggle/input/images/images/slowpoke.png
# /kaggle/input/images/images/deoxys-normal.png
# /kaggle/input/images/images/stufful.jpg
# /kaggle/input/images/images/rowlet.jpg
# /kaggle/input/images/images/manaphy.png
# /kaggle/input/images/images/nuzleaf.png
# /kaggle/input/images/images/tyrunt.png
# /kaggle/input/images/images/solrock.png
# /kaggle/input/images/images/chimecho.png
# /kaggle/input/images/images/gothorita.png
# /kaggle/input/images/images/kadabra.png
# /kaggle/input/images/images/dhelmise.jpg
# /kaggle/input/images/images/happiny.png
# /kaggle/input/images/images/decidueye.jpg
# /kaggle/input/images/images/weepinbell.png
# /kaggle/input/images/images/seismitoad.png
# /kaggle/input/images/images/clauncher.png
# /kaggle/input/images/images/pineco.png
# /kaggle/input/images/images/camerupt.png
# /kaggle/input/images/images/forretress.png
# /kaggle/input/images/images/fennekin.png
# /kaggle/input/images/images/corphish.png
# /kaggle/input/images/images/swellow.png
# /kaggle/input/images/images/pancham.png
# /kaggle/input/images/images/vanilluxe.png
# /kaggle/input/images/images/litleo.png
# /kaggle/input/images/images/starmie.png
# /kaggle/input/images/images/boldore.png
# /kaggle/input/images/images/flygon.png
# /kaggle/input/images/images/rhydon.png
# /kaggle/input/images/images/jumpluff.png
# /kaggle/input/images/images/wobbuffet.png
# /kaggle/input/images/images/snorlax.png
# /kaggle/input/images/images/stunky.png
# /kaggle/input/images/images/maractus.png
# /kaggle/input/images/images/blacephalon.jpg
# /kaggle/input/images/images/skarmory.png
# /kaggle/input/images/images/zweilous.png
# /kaggle/input/images/images/sigilyph.png
# /kaggle/input/images/images/rayquaza.png
# /kaggle/input/images/images/mienfoo.png
# /kaggle/input/images/images/rhyperior.png
# /kaggle/input/images/images/chatot.png
# /kaggle/input/images/images/lumineon.png
# /kaggle/input/images/images/binacle.png
# /kaggle/input/images/images/lunatone.png
# /kaggle/input/images/images/magnezone.png
# /kaggle/input/images/images/toxicroak.png
# /kaggle/input/images/images/oricorio-baile.jpg
# /kaggle/input/images/images/absol.png
# /kaggle/input/images/images/zapdos.png
# /kaggle/input/images/images/munchlax.png
# /kaggle/input/images/images/gastrodon.png
# /kaggle/input/images/images/kommo-o.jpg
# /kaggle/input/images/images/omanyte.png
# /kaggle/input/images/images/phione.png
# /kaggle/input/images/images/spiritomb.png
# /kaggle/input/images/images/quilava.png
# /kaggle/input/images/images/dragonair.png
# /kaggle/input/images/images/ribombee.jpg
# /kaggle/input/images/images/reuniclus.png
# /kaggle/input/images/images/seel.png
# /kaggle/input/images/images/archen.png
# /kaggle/input/images/images/swanna.png
# /kaggle/input/images/images/chinchou.png
# /kaggle/input/images/images/watchog.png
# /kaggle/input/images/images/gengar.png
# /kaggle/input/images/images/emolga.png
# /kaggle/input/images/images/shiinotic.jpg
# /kaggle/input/images/images/machamp.png
# /kaggle/input/images/images/ho-oh.png
# /kaggle/input/images/images/piloswine.png
# /kaggle/input/images/images/litten.jpg
# /kaggle/input/images/images/machoke.png
# /kaggle/input/images/images/munna.png
# /kaggle/input/images/images/noivern.png
# /kaggle/input/images/images/weezing.png
# /kaggle/input/images/images/xerneas.png
# /kaggle/input/images/images/farfetchd.png
# /kaggle/input/images/images/nidoqueen.png
# /kaggle/input/images/images/nidoran-m.png
# /kaggle/input/images/images/huntail.png
# /kaggle/input/images/images/kyogre.png
# /kaggle/input/images/images/lunala.jpg
# /kaggle/input/images/images/roserade.png
# /kaggle/input/images/images/sandygast.jpg
# /kaggle/input/images/images/golduck.png
# /kaggle/input/images/images/skrelp.png
# /kaggle/input/images/images/seviper.png
# /kaggle/input/images/images/mismagius.png
# /kaggle/input/images/images/exeggcute.png
# /kaggle/input/images/images/torchic.png
# /kaggle/input/images/images/lombre.png
# /kaggle/input/images/images/aipom.png
# /kaggle/input/images/images/clefairy.png
# /kaggle/input/images/images/hydreigon.png
# /kaggle/input/images/images/raticate.png
# /kaggle/input/images/images/kabutops.png
# /kaggle/input/images/images/staryu.png
# /kaggle/input/images/images/gurdurr.png
# /kaggle/input/images/images/blaziken.png
# /kaggle/input/images/images/mandibuzz.png
# /kaggle/input/images/images/corsola.png
# /kaggle/input/images/images/walrein.png
# /kaggle/input/images/images/yveltal.png
# /kaggle/input/images/images/braviary.png
# /kaggle/input/images/images/nihilego.jpg
# /kaggle/input/images/images/ninjask.png
# /kaggle/input/images/images/snivy.png
# /kaggle/input/images/images/unown.png
# /kaggle/input/images/images/turtwig.png
# /kaggle/input/images/images/cutiefly.jpg
# /kaggle/input/images/images/cofagrigus.png
# /kaggle/input/images/images/kricketune.png
# /kaggle/input/images/images/zygarde-50.png
# /kaggle/input/images/images/seaking.png
# /kaggle/input/images/images/poipole.jpg
# /kaggle/input/images/images/galvantula.png
# /kaggle/input/images/images/flaaffy.png
# /kaggle/input/images/images/marshtomp.png
# /kaggle/input/images/images/purugly.png
# /kaggle/input/images/images/kabuto.png
# /kaggle/input/images/images/amoonguss.png
# /kaggle/input/images/images/totodile.png
# /kaggle/input/images/images/combee.png
# /kaggle/input/images/images/vanillite.png
# /kaggle/input/images/images/pachirisu.png
# /kaggle/input/images/images/fraxure.png
# /kaggle/input/images/images/weedle.png
# /kaggle/input/images/images/hawlucha.png
# /kaggle/input/images/images/heatmor.png
# /kaggle/input/images/images/torkoal.png
# /kaggle/input/images/images/lucario.png
# /kaggle/input/images/images/incineroar.jpg
# /kaggle/input/images/images/snorunt.png
# /kaggle/input/images/images/lycanroc-midday.jpg
# /kaggle/input/images/images/hippowdon.png
# /kaggle/input/images/images/aromatisse.png
# /kaggle/input/images/images/probopass.png
# /kaggle/input/images/images/golem.png
# /kaggle/input/images/images/nidorino.png
# /kaggle/input/images/images/umbreon.png
# /kaggle/input/images/images/trumbeak.jpg
# /kaggle/input/images/images/sewaddle.png
# /kaggle/input/images/images/meowstic-male.png
# /kaggle/input/images/images/charmeleon.png
# /kaggle/input/images/images/delphox.png
# /kaggle/input/images/images/helioptile.png
# /kaggle/input/images/images/tauros.png
# /kaggle/input/images/images/purrloin.png
# /kaggle/input/images/images/deerling.png
# /kaggle/input/images/images/aron.png
# /kaggle/input/images/images/spheal.png
# /kaggle/input/images/images/ledian.png
# /kaggle/input/images/images/regice.png
# /kaggle/input/images/images/vivillon.png
# /kaggle/input/images/images/cyndaquil.png
# /kaggle/input/images/images/beartic.png
# /kaggle/input/images/images/growlithe.png
# /kaggle/input/images/images/swadloon.png
# /kaggle/input/images/images/volcanion.png
# /kaggle/input/images/images/lanturn.png
# /kaggle/input/images/images/trapinch.png
# /kaggle/input/images/images/pansage.png
# /kaggle/input/images/images/tsareena.jpg
# /kaggle/input/images/images/pheromosa.jpg
# /kaggle/input/images/images/yanmega.png
# /kaggle/input/images/images/meganium.png
# /kaggle/input/images/images/houndoom.png
# /kaggle/input/images/images/luxio.png
# /kaggle/input/images/images/sandile.png
# /kaggle/input/images/images/salamence.png
# /kaggle/input/images/images/mightyena.png
# /kaggle/input/images/images/alomomola.png
# /kaggle/input/images/images/electrode.png
# /kaggle/input/images/images/slurpuff.png
# /kaggle/input/images/images/beedrill.png
# /kaggle/input/images/images/politoed.png
# /kaggle/input/images/images/vulpix.png
# /kaggle/input/images/images/poochyena.png
# /kaggle/input/images/images/trevenant.png
# /kaggle/input/images/images/primarina.jpg
# /kaggle/input/images/images/zeraora.jpg
# /kaggle/input/images/images/rotom.png
# /kaggle/input/images/images/virizion.png
# /kaggle/input/images/images/gogoat.png
# /kaggle/input/images/images/mimikyu.jpg
# /kaggle/input/images/images/ampharos.png
# /kaggle/input/images/images/timburr.png
# /kaggle/input/images/images/ambipom.png
# /kaggle/input/images/images/porygon2.png
# /kaggle/input/images/images/rattata.png
# /kaggle/input/images/images/gourgeist-average.png
# /kaggle/input/images/images/wailord.png
# /kaggle/input/images/images/caterpie.png
# /kaggle/input/images/images/bayleef.png
# /kaggle/input/images/images/slugma.png
# /kaggle/input/images/images/wailmer.png
# /kaggle/input/images/images/scizor.png
# /kaggle/input/images/images/mareep.png
# /kaggle/input/images/images/swablu.png
# /kaggle/input/images/images/fomantis.jpg
# /kaggle/input/images/images/terrakion.png
# /kaggle/input/images/images/aerodactyl.png
# /kaggle/input/images/images/gliscor.png
# /kaggle/input/images/images/cottonee.png
# /kaggle/input/images/images/entei.png
# /kaggle/input/images/images/jigglypuff.png
# /kaggle/input/images/images/wishiwashi-solo.jpg
# /kaggle/input/images/images/golisopod.jpg
# /kaggle/input/images/images/beheeyem.png
# /kaggle/input/images/images/magmortar.png
# /kaggle/input/images/images/crawdaunt.png
# /kaggle/input/images/images/gothitelle.png
# /kaggle/input/images/images/mantine.png
# /kaggle/input/images/images/remoraid.png
# /kaggle/input/images/images/rampardos.png
# /kaggle/input/images/images/donphan.png
# /kaggle/input/images/images/bidoof.png
# /kaggle/input/images/images/klang.png
# /kaggle/input/images/images/fletchinder.png
# /kaggle/input/images/images/burmy.png
# /kaggle/input/images/images/duskull.png
# /kaggle/input/images/images/skiploom.png
# /kaggle/input/images/images/tentacool.png
# /kaggle/input/images/images/honedge.png
# /kaggle/input/images/images/grovyle.png
# /kaggle/input/images/images/dewgong.png
# /kaggle/input/images/images/rapidash.png
# /kaggle/input/images/images/bruxish.jpg
# /kaggle/input/images/images/frogadier.png
# /kaggle/input/images/images/starly.png
# /kaggle/input/images/images/froakie.png
# /kaggle/input/images/images/cradily.png
# /kaggle/input/images/images/graveler.png
# /kaggle/input/images/images/araquanid.jpg
# /kaggle/input/images/images/elekid.png
# /kaggle/input/images/images/psyduck.png
# /kaggle/input/images/images/cobalion.png
# /kaggle/input/images/images/mantyke.png
# /kaggle/input/images/images/darkrai.png
# /kaggle/input/images/images/victreebel.png
# /kaggle/input/images/images/wooper.png
# /kaggle/input/images/images/stantler.png
# /kaggle/input/images/images/magikarp.png
# /kaggle/input/images/images/darumaka.png
# /kaggle/input/images/images/tangela.png
# /kaggle/input/images/images/koffing.png
# /kaggle/input/images/images/pikipek.jpg
# /kaggle/input/images/images/rufflet.png
# /kaggle/input/images/images/drowzee.png
# /kaggle/input/images/images/krokorok.png
# /kaggle/input/images/images/tynamo.png
# /kaggle/input/images/images/heliolisk.png
# /kaggle/input/images/images/espurr.png
# /kaggle/input/images/images/wormadam-plant.png
# /kaggle/input/images/images/minccino.png
# /kaggle/input/images/images/ducklett.png
# /kaggle/input/images/images/palpitoad.png
# /kaggle/input/images/images/tangrowth.png
# /kaggle/input/images/images/hoothoot.png
# /kaggle/input/images/images/magby.png
# /kaggle/input/images/images/rhyhorn.png
# /kaggle/input/images/images/swirlix.png
# /kaggle/input/images/images/mime-jr.png
# /kaggle/input/images/images/grimer.png
# /kaggle/input/images/images/electrike.png
# /kaggle/input/images/images/sneasel.png
# /kaggle/input/images/images/mamoswine.png
# /kaggle/input/images/images/chikorita.png
# /kaggle/input/images/images/espeon.png
# /kaggle/input/images/images/servine.png
# /kaggle/input/images/images/zoroark.png
# /kaggle/input/images/images/cascoon.png
# /kaggle/input/images/images/poliwag.png
# /kaggle/input/images/images/klefki.png
# /kaggle/input/images/images/cosmog.jpg
# /kaggle/input/images/images/meltan.jpg
# /kaggle/input/images/images/sealeo.png
# /kaggle/input/images/images/prinplup.png
# /kaggle/input/images/images/bergmite.png
# /kaggle/input/images/images/phanpy.png
# /kaggle/input/images/images/snover.png
# /kaggle/input/images/images/sliggoo.png
# /kaggle/input/images/images/claydol.png
# /kaggle/input/images/images/wimpod.jpg
# /kaggle/input/images/images/pidgeotto.png
# /kaggle/input/images/images/amaura.png
# /kaggle/input/images/images/hariyama.png
# /kaggle/input/images/images/wurmple.png
# /kaggle/input/images/images/buizel.png
# /kaggle/input/images/images/milotic.png
# /kaggle/input/images/images/yanma.png
# /kaggle/input/images/images/charizard.png
# /kaggle/input/images/images/arcanine.png
# /kaggle/input/images/images/metapod.png
# /kaggle/input/images/images/bouffalant.png
# /kaggle/input/images/images/gligar.png
# /kaggle/input/images/images/persian.png
# /kaggle/input/images/images/spewpa.png
# /kaggle/input/images/images/talonflame.png
# /kaggle/input/images/images/regirock.png
# /kaggle/input/images/images/silcoon.png
# /kaggle/input/images/images/teddiursa.png
# /kaggle/input/images/images/staraptor.png
# /kaggle/input/images/images/joltik.png
# /kaggle/input/images/images/ralts.png
# /kaggle/input/images/images/stakataka.jpg
# /kaggle/input/images/images/morelull.jpg
# /kaggle/input/images/images/suicune.png
# /kaggle/input/images/images/slaking.png
# /kaggle/input/images/images/beautifly.png
# /kaggle/input/images/images/altaria.png
# /kaggle/input/images/images/primeape.png
# /kaggle/input/images/images/hitmontop.png
# /kaggle/input/images/images/kartana.jpg
# /kaggle/input/images/images/jellicent.png
# /kaggle/input/images/images/registeel.png
# /kaggle/input/images/images/slakoth.png
# /kaggle/input/images/images/tyrantrum.png
# /kaggle/input/images/images/bellsprout.png
# /kaggle/input/images/images/manectric.png
# /kaggle/input/images/images/fletchling.png
# /kaggle/input/images/images/shelmet.png
# /kaggle/input/images/images/foongus.png
# /kaggle/input/images/images/celebi.png
# /kaggle/input/images/images/shelgon.png
# /kaggle/input/images/images/shellos.png
# /kaggle/input/images/images/tentacruel.png
# /kaggle/input/images/images/linoone.png
# /kaggle/input/images/images/brionne.jpg
# /kaggle/input/images/images/yungoos.jpg
# /kaggle/input/images/images/baltoy.png
# /kaggle/input/images/images/pikachu.png
# /kaggle/input/images/images/spoink.png
# /kaggle/input/images/images/abra.png
# /kaggle/input/images/images/relicanth.png
# /kaggle/input/images/images/goodra.png
# /kaggle/input/images/images/meditite.png
# /kaggle/input/images/images/vespiquen.png
# /kaggle/input/images/images/dragalge.png
# /kaggle/input/images/images/flareon.png
# /kaggle/input/images/images/leavanny.png
# /kaggle/input/images/images/solosis.png
# /kaggle/input/images/images/lampent.png
# /kaggle/input/images/images/turtonator.jpg
# /kaggle/input/images/images/shuckle.png
# /kaggle/input/images/images/elgyem.png
# /kaggle/input/images/images/jangmo-o.jpg
# /kaggle/input/images/images/chespin.png
# /kaggle/input/images/images/pidgeot.png
# /kaggle/input/images/images/woobat.png
# /kaggle/input/images/images/palkia.png
# /kaggle/input/images/images/oshawott.png
# /kaggle/input/images/images/braixen.png
# /kaggle/input/images/images/marowak.png
# /kaggle/input/images/images/zubat.png
# /kaggle/input/images/images/treecko.png
# /kaggle/input/images/images/scyther.png
# /kaggle/input/images/images/octillery.png
# /kaggle/input/images/images/gloom.png
# /kaggle/input/images/images/scraggy.png
# /kaggle/input/images/images/tranquill.png
# /kaggle/input/images/images/steelix.png
# /kaggle/input/images/images/lickitung.png
# /kaggle/input/images/images/tapu-lele.jpg
# /kaggle/input/images/images/cherubi.png
# /kaggle/input/images/images/chesnaught.png
# /kaggle/input/images/images/simisear.png
# /kaggle/input/images/images/qwilfish.png
# /kaggle/input/images/images/electivire.png
# /kaggle/input/images/images/nincada.png
# /kaggle/input/images/images/piplup.png
# /kaggle/input/images/images/trubbish.png
# /kaggle/input/images/images/dusknoir.png
# /kaggle/input/images/images/heatran.png
# /kaggle/input/images/images/ludicolo.png
# /kaggle/input/images/images/poliwhirl.png
# /kaggle/input/images/images/drampa.jpg
# /kaggle/input/images/images/pansear.png
# /kaggle/input/images/images/gible.png
# /kaggle/input/images/images/lilligant.png
# /kaggle/input/images/images/marshadow.jpg
# /kaggle/input/images/images/malamar.png
# /kaggle/input/images/images/meowth.png
# /kaggle/input/images/images/togekiss.png
# /kaggle/input/images/images/shedinja.png
# /kaggle/input/images/images/haxorus.png
# /kaggle/input/images/images/stunfisk.png
# /kaggle/input/images/images/nosepass.png
# /kaggle/input/images/images/shellder.png
# /kaggle/input/images/images/spritzee.png
# /kaggle/input/images/images/igglybuff.png
# /kaggle/input/images/images/chansey.png
# /kaggle/input/images/images/reshiram.png
# /kaggle/input/images/images/stoutland.png
# /kaggle/input/images/images/torracat.jpg
# /kaggle/input/images/images/mothim.png
# /kaggle/input/images/images/muk.png
# /kaggle/input/images/images/musharna.png
# /kaggle/input/images/images/feebas.png
# /kaggle/input/images/images/chandelure.png
# /kaggle/input/images/images/uxie.png
# /kaggle/input/images/images/sawsbuck.png
# /kaggle/input/images/images/hippopotas.png
# /kaggle/input/images/images/moltres.png
# /kaggle/input/images/images/hoopa-confined.png
# /kaggle/input/images/images/buzzwole.jpg
# /kaggle/input/images/images/cacnea.png
# /kaggle/input/images/images/pyroar.png
# /kaggle/input/images/images/magneton.png
# /kaggle/input/images/images/roggenrola.png
# /kaggle/input/images/images/monferno.png
# /kaggle/input/images/images/clefable.png
# /kaggle/input/images/images/blitzle.png
# /kaggle/input/images/images/greninja.png
# /kaggle/input/images/images/salazzle.jpg
# /kaggle/input/images/images/exeggutor.png
# /kaggle/input/images/images/jynx.png
# /kaggle/input/images/images/drapion.png
# /kaggle/input/images/images/gabite.png
# /kaggle/input/images/images/crabominable.jpg
# /kaggle/input/images/images/omastar.png
# /kaggle/input/images/images/audino.png
# /kaggle/input/images/images/shieldon.png
# /kaggle/input/images/images/gigalith.png
# /kaggle/input/images/images/dewpider.jpg
# /kaggle/input/images/images/ledyba.png
# /kaggle/input/images/images/riolu.png

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df1 = pd.read_csv('/kaggle/input/pokemon.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'pokemon.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 809 rows and 3 columns

# %%
df1.head(5)
# Out:
#          Name  Type1   Type2
# 0   bulbasaur  Grass  Poison
# 1     ivysaur  Grass  Poison
# 2    venusaur  Grass  Poison
# 3  charmander   Fire     NaN
# 4  charmeleon   Fire     NaN

# %%
plotPerColumnDistribution(df1, 10, 5)
